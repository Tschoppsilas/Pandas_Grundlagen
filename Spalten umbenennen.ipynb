# %%
import pandas as pd

# %%
df = pd.read_csv("customers.csv", index_col = "ID")

# %%
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %% [markdown]
# # Spalten umbenennen

# %%
df.rename(columns = {"First Name": "first_name"})
# Out:
#      first_name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37
# ...         ...       ...           ...          ...
# 7099      David    Harris  809-428-6034  $12,799.04
# 6743      Henry     Reyes  999-363-7716  $11,043.94
# 3513     Olivia   Sanders             ?  $10,206.00
# 4307       Emma       Cox  748-415-4613   $9,839.57
# 9062      Henry     Brown  412-368-2550  $14,686.60
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Zeilen umbenennen

# %%
df.rename(index={4576: "4576_Sophia"})
df.head()
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %% [markdown]
# # Dauerhafte Änderungen

# %%
df.head() #Man sieht es ist nicht permanent
# Out:
#      First Name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename(columns = {"First Name": "first_name"}, inplace = True) #hier wird es permanent

# %%
df.head()
# Out:
#      first_name Last Name         Phone          LTV
# ID
# 4576     Sophia    Walker  602-310-9331     $496.87
# 9488     Evelyn    Harris  171-363-6978  $38,424.41
# 7265      Lucas    Foster  139-658-8905  $14,413.64
# 8555     Elijah     Jones  538-241-9868  $13,440.49
# 7023      Mason    Taylor  937-595-5837   $1,777.37

# %%
df.rename(
    index={
        4576: "4576_Sophia",
        9488 : "9488_Evelyn"
    },
    columns = {
        "First Name": "first_name",
        "Second Name": "second_name",
        "Phone": "phone",
        "LTV": "livetime_valie"
    }, inplace = True)

# %%
df.head()
# Out:
#             first_name Last Name         phone livetime_valie
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331       $496.87
# 9488_Evelyn     Evelyn    Harris  171-363-6978    $38,424.41
# 7265             Lucas    Foster  139-658-8905    $14,413.64
# 8555            Elijah     Jones  538-241-9868    $13,440.49
# 7023             Mason    Taylor  937-595-5837     $1,777.37

# %% [markdown]
# # Error wenn unbenennen nicht möglich

# %%
df.rename(
    columns = {
        "phone": "phone_number",
        "Adress": "adress"
    }
)
# Out:
#             first_name Last Name  phone_number livetime_valie
# ID
# 4576_Sophia     Sophia    Walker  602-310-9331       $496.87
# 9488_Evelyn     Evelyn    Harris  171-363-6978    $38,424.41
# 7265             Lucas    Foster  139-658-8905    $14,413.64
# 8555            Elijah     Jones  538-241-9868    $13,440.49
# 7023             Mason    Taylor  937-595-5837     $1,777.37
# ...                ...       ...           ...            ...
# 7099             David    Harris  809-428-6034    $12,799.04
# 6743             Henry     Reyes  999-363-7716    $11,043.94
# 3513            Olivia   Sanders             ?    $10,206.00
# 4307              Emma       Cox  748-415-4613     $9,839.57
# 9062             Henry     Brown  412-368-2550    $14,686.60
#
# [1000 rows x 4 columns]

# %%
df.rename(
    columns = {
        "phone": "phone_number",
        "Adress": "adress"
    },
    errors="raise"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10876\297995222.py in ?()
# ----> 1 df.rename(
#       2     columns = {
#       3         "phone": "phone_number",
#       4         "Adress": "adress"
#
# ~\miniconda3\envs\Testenv\Lib\site-packages\pandas\core\frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5770         0  1  4
#    5771         2  2  5
#    5772         4  3  6
#    5773         """
# -> 5774         return super()._rename(
#    5775             mapper=mapper,
#    5776             index=index,
#    5777             columns=columns,
#
# ~\miniconda3\envs\Testenv\Lib\site-packages\pandas\core\generic.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1126                         label
#    1127                         for index, label in enumerate(replacements)
# ...
